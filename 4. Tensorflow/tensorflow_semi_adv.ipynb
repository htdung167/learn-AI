# %% [markdown]
# <a href="https://colab.research.google.com/github/htdung167/learn-machine-learning/blob/main/4.%20Tensorflow/tensorflow_semi_adv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Categorical Crossentropy**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

# %%
y_true = [[0,1,0],[0,0,1]]
y_pred = [[0.05, 0.95, 0], [0.1, 0.8, 0.1]]
y_pred = tf.convert_to_tensor(y_pred)

# Categorical Crossentropy
ce_func = tf.keras.losses.CategoricalCrossentropy()
loss = ce_func(y_true, y_pred)

print(loss.numpy())
# Out:
# 1.1769392

# %%
y_true = [1,2]
y_pred = [[0.05, 0.95, 0], [0.1, 0.8, 0.1]]
y_pred = tf.convert_to_tensor(y_pred)

# Sparse Categorical Crossentropy
ce_func = tf.keras.losses.SparseCategoricalCrossentropy()
loss = ce_func(y_true, y_pred)

print(loss.numpy())
# Out:
# 1.1769392
